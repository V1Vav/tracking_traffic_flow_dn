# %%
from ultralytics import YOLO
import os

# %%
CUR_DIR = os.getcwd()
# DATA_NAME = "640-Hutech-Vehicle-1"
DATA_NAME = "vehicle-u1nn1"
DATA_YAML = f"{CUR_DIR}\{DATA_NAME}\data.yaml"

# print(DATA_YAML)

assert os.path.exists(DATA_YAML), "Không tìm thấy data.yaml"
print("Dataset OK")
# Out:
# Dataset OK

# %%
MODEL_DIR = f"{CUR_DIR}\..\models"
model_name = "yolov8s.pt"

model = YOLO(f"{MODEL_DIR}\{model_name}")
print("Loaded pretrained model")
# Out:
# ...
# Loaded pretrained model

# %%
from datetime import datetime

# config
EPOCHS = 50

# tạo tên theo date + epoch
date_str = datetime.now().strftime("%Y%m%d_%H%M")
run_name = f"traffic_{date_str}_e{EPOCHS}"

print("Run name:", run_name)
# Out:
# Run name: traffic_20260627_2112_e50

# %%
model.train(
    data=DATA_YAML,
    epochs=EPOCHS,
    imgsz=640,
    batch=8,
    device=0,
    name=run_name,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.80 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.35  Python-3.11.2 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
