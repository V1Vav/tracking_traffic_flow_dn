# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("ngohoangphuc").project("640-hutech-vehicle-nq2ts")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.3.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in G:\Softwares\Python\Lib\site-packages (from roboflow) (2024.2.2)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in G:\Softwares\Python\Lib\site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in G:\Softwares\Python\Lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in G:\Softwares\Python\Lib\site-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in G:\Softwares\Python\Lib\site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in G:\Softwares\Python\Lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in G:\Softwares\Python\Lib\site-packages (from roboflow) (11.0.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.3.0-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: python-dateutil in G:\Softwares\Python\Lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in G:\Softwares\Python\Lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in G:\Softwares\Python\Lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in G:\Softwares\Python\Lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in G:\Softwares\Python\Lib\site-packages (from roboflow) (1.26.15)
# Requirement already satisfied: tqdm>=4.41.0 in G:\Softwares\Python\Lib\site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in G:\Softwares\Python\Lib\site-packages (from roboflow) (5.4.1)
# Requirement already satisfied: requests_toolbelt in G:\Softwares\Python\Lib\site-packages (from roboflow) (0.10.1)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting typer>=0.12.0 (from roboflow)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Collecting Pillow>=7.1.2 (from roboflow)
#   Downloading pillow-12.2.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: colorama in G:\Softwares\Python\Lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Collecting click>=8.2.1 (from typer>=0.12.0->roboflow)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.12.0->roboflow)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=13.8.0 in G:\Softwares\Python\Lib\site-packages (from typer>=0.12.0->roboflow) (13.9.4)
# Collecting annotated-doc>=0.0.2 (from typer>=0.12.0->roboflow)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in G:\Softwares\Python\Lib\site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in G:\Softwares\Python\Lib\site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in G:\Softwares\Python\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in G:\Softwares\Python\Lib\site-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in G:\Softwares\Python\Lib\site-packages (from matplotlib->roboflow) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in G:\Softwares\Python\Lib\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in G:\Softwares\Python\Lib\site-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in G:\Softwares\Python\Lib\site-packages (from requests->roboflow) (3.1.0)
# Downloading roboflow-1.3.7-py3-none-any.whl (195 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading pi_heif-1.3.0-cp311-cp311-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/1.9 MB 2.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/1.9 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/1.9 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 2.4 MB/s  0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.9 MB 2.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.9 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.9 MB 2.3 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.9 MB 2.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.9 MB 2.4 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.9 MB 2.4 MB/s eta 0:00:03
#    --------------- ------------------------ 3.9/9.9 MB 2.4 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/9.9 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.9 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.9 MB 2.5 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.9 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 2.7 MB/s  0:00:03
# Downloading pillow-12.2.0-cp311-cp311-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.1 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/7.1 MB 3.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/7.1 MB 3.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.1 MB 3.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.9/7.1 MB 3.0 MB/s eta 0:00:02
#    ------------------- -------------------- 3.4/7.1 MB 3.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.2/7.1 MB 3.0 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.1 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.1 MB 3.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.8/7.1 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 3.0 MB/s  0:00:02
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, shellingham, Pillow, idna, click, annotated-doc, pi-heif, typer, roboflow
#
#    ---- -----------------------------------  1/10 [filetype]
#    -------- -------------------------------  2/10 [shellingham]
#   Attempting uninstall: Pillow
#    -------- -------------------------------  2/10 [shellingham]
#     Found existing installation: pillow 11.0.0
#    -------- -------------------------------  2/10 [shellingham]
#     Uninstalling pillow-11.0.0:
#    -------- -------------------------------  2/10 [shellingham]
#       Successfully uninstalled pillow-11.0.0
#    -------- -------------------------------  2/10 [shellingham]
#    ------------ ---------------------------  3/10 [Pillow]
#    ------------ ---------------------------  3/10 [Pillow]
#    ------------ ---------------------------  3/10 [Pillow]
#    ------------ ---------------------------  3/10 [Pillow]
#    ------------ ---------------------------  3/10 [Pillow]
#    ------------ ---------------------------  3/10 [Pillow]
#   Attempting uninstall: idna
#    ------------ ---------------------------  3/10 [Pillow]
#     Found existing installation: idna 3.4
#    ------------ ---------------------------  3/10 [Pillow]
#    ---------------- -----------------------  4/10 [idna]
#     Uninstalling idna-3.4:
#    ---------------- -----------------------  4/10 [idna]
#       Successfully uninstalled idna-3.4
#    ---------------- -----------------------  4/10 [idna]
#   Attempting uninstall: click
#    ---------------- -----------------------  4/10 [idna]
#     Found existing installation: click 8.1.3
#    ---------------- -----------------------  4/10 [idna]
#     Uninstalling click-8.1.3:
#    ---------------- -----------------------  4/10 [idna]
#       Successfully uninstalled click-8.1.3
#    ---------------- -----------------------  4/10 [idna]
#    -------------------- -------------------  5/10 [click]
#    -------------------- -------------------  5/10 [click]
#    ---------------------------- -----------  7/10 [pi-heif]
#   Attempting uninstall: typer
#    ---------------------------- -----------  7/10 [pi-heif]
#     Found existing installation: typer 0.9.4
#    ---------------------------- -----------  7/10 [pi-heif]
#     Uninstalling typer-0.9.4:
#    ---------------------------- -----------  7/10 [pi-heif]
#       Successfully uninstalled typer-0.9.4
#    ---------------------------- -----------  7/10 [pi-heif]
#    -------------------------------- -------  8/10 [typer]
#    ------------------------------------ ---  9/10 [roboflow]
#    ------------------------------------ ---  9/10 [roboflow]
#    ------------------------------------ ---  9/10 [roboflow]
#    ------------------------------------ ---  9/10 [roboflow]
#    ------------------------------------ ---  9/10 [roboflow]
#    ------------------------------------ ---  9/10 [roboflow]
#    ---------------------------------------- 10/10 [roboflow]
#
# Successfully installed Pillow-12.2.0 annotated-doc-0.0.4 click-8.3.3 filetype-1.2.0 idna-3.7 pi-heif-1.3.0 pillow-avif-plugin-1.5.5 roboflow-1.3.7 shellingham-1.5.4 typer-0.25.1
# WARNING: Ignoring invalid distribution ~orch (G:\Softwares\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (G:\Softwares\Python\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mitmproxy 10.2.4 requires asgiref<3.8,>=3.2.10, but you have asgiref 3.8.1 which is incompatible.
# mitmproxy 10.2.4 requires protobuf<5,>=3.14, but you have protobuf 6.31.1 which is incompatible.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.25.1 which is incompatible.
# streamlit 1.41.1 requires pillow<12,>=7.1.0, but you have pillow 12.2.0 which is incompatible.
# streamlit 1.41.1 requires protobuf<6,>=3.20, but you have protobuf 6.31.1 which is incompatible.
# tensorflow-intel 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.26.4 which is incompatible.
# tensorflow-intel 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.31.1 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.25.1 which is incompatible.
# WARNING: Ignoring invalid distribution ~orch (G:\Softwares\Python\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in 640-Hutech-Vehicle-1 to yolov8:: 100%|██████████| 262644/262644 [02:04<00:00, 2110.65it/s]
# Extracting Dataset Version Zip to 640-Hutech-Vehicle-1 in yolov8:: 100%|██████████| 6750/6750 [00:01<00:00, 4089.00it/s]
